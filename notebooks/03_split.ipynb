# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("ml_table_labeled.csv", parse_dates=["order_purchase_timestamp"])

df = df.sort_values("order_purchase_timestamp")

n = len(df)
train_end = int(n * 0.7)
val_end = int(n * 0.85)

train = df.iloc[:train_end]
val = df.iloc[train_end:val_end]
test = df.iloc[val_end:]

print("Train:", train.shape, train["is_late"].mean())
print("Val:", val.shape, val["is_late"].mean())
print("Test:", test.shape, test["is_late"].mean())

train.to_csv("train.csv", index=False)
val.to_csv("val.csv", index=False)
test.to_csv("test.csv", index=False)
# Out:
# Train: (67533, 17) 0.0902817881628241
# Val: (14471, 17) 0.053417179185958126
# Test: (14472, 17) 0.06612769485903815
