# %%
import pandas as pd
import numpy as np

train = pd.read_csv("train.csv", parse_dates=["order_purchase_timestamp"])
val = pd.read_csv("val.csv", parse_dates=["order_purchase_timestamp"])
test = pd.read_csv("test.csv", parse_dates=["order_purchase_timestamp"])

print(train.shape, val.shape, test.shape)
# Out:
# (67533, 17) (14471, 17) (14472, 17)

# %%
import sys
sys.path.append("..")
from src.features import add_features, FEATURE_COLUMNS

# %%
train_fe = add_features(train)
val_fe = add_features(val)
test_fe = add_features(test)

print(train_fe[["total_price", "log_total_price"]].describe())
# Out:
#         total_price  log_total_price
# count  67533.000000     67533.000000
# mean     135.884499         4.452692
# std      205.187627         0.916037
# min        2.290000         1.190888
# 25%       45.900000         3.848018
# 50%       85.000000         4.454347
# 75%      149.900000         5.016617
# max    13440.000000         9.506065

# %%
train_fe.columns.tolist()
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date',
#  'num_items',
#  'total_price',
#  'total_freight',
#  'seller_id',
#  'num_unique_sellers',
#  'seller_state',
#  'num_payments',
#  'total_payment_value',
#  'customer_state',
#  'same_state',
#  'is_late',
#  'purchase_month',
#  'purchase_dayofweek',
#  'log_total_price']

# %%
features = [
    "num_items", "total_freight", "log_total_price",  
    "num_payments", "total_payment_value",
    "purchase_month", "purchase_dayofweek",
    "same_state", "num_unique_sellers"
]

train_fe[features + ["is_late"]].to_csv("train_features.csv", index=False)
val_fe[features + ["is_late"]].to_csv("val_features.csv", index=False)
test_fe[features + ["is_late"]].to_csv("test_features.csv", index=False)

print("Features saved:", features)
# Out:
# Features saved: ['num_items', 'total_freight', 'log_total_price', 'num_payments', 'total_payment_value', 'purchase_month', 'purchase_dayofweek', 'same_state', 'num_unique_sellers']
